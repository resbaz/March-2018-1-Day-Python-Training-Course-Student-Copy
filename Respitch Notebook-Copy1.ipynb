# %%
import urllib3
import itertools
import numpy as np

# %%
# import word list

http = urllib3.PoolManager()
target_url = "http://www.sil.org/linguistics/wordlists/english/wordlist/wordsEn.txt"
r = http.request('GET',target_url)
wordlist = str(r.data.decode('utf-8')).split('\r\n')

# %%
### Here we make a function that tells us whether or not its an english word

english_words = set(word.strip().lower() for word in wordlist)
def is_english_word(word):
    return word.lower() in english_words

print(is_english_word("ham"))
# Out:
# True

# %%
print(is_english_word('larvae'))
# Out:
# True

# %%
def string_combos(string):
    num = len(string)
    ans = list()
    for t in range(0,num):
        num2 = num-t
        itr1 = itertools.permutations(string,num2)
        for itr in itr1:
            wrd = ''.join(itr)
            ans.append(wrd)
    return ans

# %%
string_combos('abcd')
# Out:
# ['abcd',
#  'abdc',
#  'acbd',
#  'acdb',
#  'adbc',
#  'adcb',
#  'bacd',
#  'badc',
#  'bcad',
#  'bcda',
#  'bdac',
#  'bdca',
#  'cabd',
#  'cadb',
#  'cbad',
#  'cbda',
#  'cdab',
#  'cdba',
#  'dabc',
#  'dacb',
#  'dbac',
#  'dbca',
#  'dcab',
#  'dcba',
#  'abc',
#  'abd',
#  'acb',
#  'acd',
#  'adb',
#  'adc',
#  'bac',
#  'bad',
#  'bca',
#  'bcd',
#  'bda',
#  'bdc',
#  'cab',
#  'cad',
#  'cba',
#  'cbd',
#  'cda',
#  'cdb',
#  'dab',
#  'dac',
#  'dba',
#  'dbc',
#  'dca',
#  'dcb',
#  'ab',
#  'ac',
#  'ad',
#  'ba',
#  'bc',
#  'bd',
#  'ca',
#  'cb',
#  'cd',
#  'da',
#  'db',
#  'dc',
#  'a',
#  'b',
#  'c',
#  'd']

# %% [markdown]
# # You Already know how to Code!
#
# ![image.png](attachment:image.png)

# %%
b = [1,2,3]
np.mean(b)  #a function that calculates the mean
# Out:
# 2.0

# %% [markdown]
# ## So Lets look at some more magical doodads/ Functions!
#
# ### We need a list of all Possible combinations of our letters right?
#
# ### Behold! String_Combos()
#
# ![alt text](http://25.media.tumblr.com/c66c15ce6ad3bb8c4268e254d4d0353d/tumblr_mof2n474yG1s0teago2_400.gif "Logo Title Text 1")
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # What does it do (In English Please!):
#
# ### string_combos creates a list of all the possible combinations of a string of letters
#
# ## or
#
# ### [List of all possible combinations of letters] = string_combos( some letters)

# %%
letters = "abc" # Lets make some letters

combos = string_combos(letters) # find all the combos of that

print(combos)  #Show me the list (I hope its actual combos, I'm hungry!)
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba', 'ab', 'ac', 'ba', 'bc', 'ca', 'cb', 'a', 'b', 'c']

# %% [markdown]
# ### How do we know its an english word though?
#
# ## Meet Magic Doodad Number 2! - is_english_word()
#
# ### In English: is_english_word() tells you whether or not the string of letters you input is an English word or not
#
# ## or
#
# ### Plain Talk: the truth = is_english_word(someletters)

# %%
the_truth = is_english_word("truth")
print(the_truth)
# Out:
# True

# %%
bullhonkey = is_english_word('bullhonkey')
print(bullhonkey)
# Out:
# False

# %% [markdown]
# ### How do you know the Truth Computer?
# ![image.png](attachment:image.png)
#
# ### What will we do with the logic?
#
# ### Use it to tell the computer when to do what we want with an if statement:
#
# ### Plain Talk:
#
# If something is true, then do this action to this thing
#
# ### Python Talk:
#
# if something is True:
#
#     action(thing)

# %%
something = is_english_word('something')

if something is True:
    print('well thats something!')
# Out:
# well thats something!

# %% [markdown]
# ### Now we need to do this for every possible combination right?
#
# ### if only we could go through each combination in our string combos output.......
#
#
# ## We can get loopy!  - Behold the for loop:
#
# ### Plain talk:
#
# For every item in our list, perform an action on that item
#
# ### Python Talk:
#
# for item in list:
#
#     action(item)

# %%
p_list = ['a',True,'c']

for char in p_list:
    print(char)
# Out:
# a
# True
# c

# %%
for char in p_list:
    if char is True:
        print(char)
        print("The truth! you can't handle the truth!")
# Out:
# True
# The truth! you can't handle the truth!

# %% [markdown]
# ## We now have the building blocks to hack Letters and numbers (or countdown if you a Brit)
#
#
# ### Remember our "Pseudocode"
#
#    - Enter the nine letters into Python
#    - Find all possible combinations of the word (Hint, string_combos!!)
#    - Go through each combination (Hint:I think we have something FOR that?)
#
#        - Find out if that combo is a word (cmon Harry don't you have something in your pocket for this?)
#        - if the combo is a word...... (IF only we had a solution for that)
#
#            - .....Then maybe show it? (if only we could PRINT it off!)

# %%
# Type in your answer code here:

# %% [markdown]
# #### Tabled material for now!!!

# %%
for bs in b:
    print(bs+2)
# Out:
# 3
# 4
# 5

# %%
#Its Logic Spock!!!

the_truth = True
Fake_news = False

# %%
if the_truth is True:
    print('well that was tautological!')
# Out:
# well that was tautological!

# %%
if Fake_news is True:
    print("Oh NO Trump was right!")

# %%
if Fake_news is True:
   print("Oh NO Trump was right!")
else:
   print("phew worldview is still relevant")
# Out:
# phew worldview is still relevant

# %%
#combining the two
outlist = list()

for thing in anything:
    if thing is 1:
        print('you are the one!')
        outlist.append('one')
outlist
# Out:
# you are the one!
# ['one']

# %%
# output

letters = 'abcemnopq'

combs = string_combis()

# %%
anything = [b,1,'hello world', 4,5.5]
print(anything)
# Out:
# [[1, 2, 3], 1, 'hello world', 4, 5.5]

# %% [markdown]
# You can select a subset of a list

# %%
print(anything[0]) #wait 0? no way
print(anything[1:4])
print(b[-1])
print(b[-2])
# Out:
# [1, 2, 3]
# [1, 'hello world', 4]
# 3
# 2

# %% [markdown]
# And add New items to the end of a string list

# %%
anything.append(b)
print(anything)
# Out:
# [[1, 2, 3], 1, 'hello world', 4, 5.5, [1, 2, 3], [1, 2, 3]]

# %%
empty_list = list() #builds an empty list
empty_list.append(anything)
print(empty_list)
# Out:
# [[[1, 2, 3], 1, 'hello world', 4, 5.5, [1, 2, 3], [1, 2, 3]]]

# %%
s = 'Hey world'
print(s)
# Out:
# Hey world

# %%
#Strings are list in a sense
print(s[1])
# Out:
# e

# %%
print(s[0:4])
# Out:
# Hey

# %%
is_english_word('walrus')
# Out:
# True

# %% [markdown]
# Now, onto Strings
#
#
# ![alt text](http://25.media.tumblr.com/c66c15ce6ad3bb8c4268e254d4d0353d/tumblr_mof2n474yG1s0teago2_400.gif "Logo Title Text 1")

# %%
cr = 'Come Together'
cr = cr.lower()

cr = cr.replace(' ','')

cr_u = ''.join([char for index, char in enumerate(cr) if char not in cr[0:index]])

# %%
print(len(cr_u))
print(cr_u)
# Out:
# 8
# cometghr

# %%
import time

t0 = time.time()
cr_u = cr_u+'e'+'t'

cr_list = string_combos(cr_u)

for crs in cr_list:
    if is_english_word(crs) is True:
        print(crs)
        
t1 = time.time()

elapsed = t1-t0
# Out:
# together
# together
# together
# together
# cortege
# cortege
# cortege
# cortege
# theorem
# thereto
# theorem
# thereto
# trochee
# trochee
# theorem
# thereto
# theorem
# thereto
# trochee
# trochee
# cometh
# cometh
# cometh
# cometh
# cotter
# cotter
# cohere
# cohere
# cotter
# cotter
# cermet
# cermet
# chrome
# chrome
# cermet
# cermet
# mother
# mother
# mother
# mother
# meteor
# meteor
# meteor
# meteor
# echoer
# emoter
# emoter
# etcher
# etcher
# tother
# tother
# tether
# troche
# troche
# tether
# goethe
# goethe
# goethe
# goethe
# getter
# getter
# ghetto
# ghetto
# ghetto
# ghetto
# getter
# getter
# hotter
# hotter
# hotter
# hotter
# hector
# hector
# hetero
# hereto
# hereto
# hetero
# hector
# hector
# hetero
# hereto
# hereto
# hetero
# remote
# remote
# reecho
# remote
# remote
# reecho
# echoer
# emoter
# emoter
# etcher
# etcher
# tother
# tother
# tether
# troche
# troche
# tether
# comet
# comer
# comet
# comte
# comte
# comet
# comer
# comet
# comte
# ...

# %%
elapsed
# Out:
# 86.45373296737671
